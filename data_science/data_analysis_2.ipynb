# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
transfusion = pd.read_csv('blood_transfusion.csv')

# %%
transfusion.head() # first 5  record
# Out:
#    Recency  Frequency  Monetary  Time        Class
# 0        2         50     12500    98      donated
# 1        0         13      3250    28      donated
# 2        1         16      4000    35      donated
# 3        2         20      5000    45      donated
# 4        1         24      6000    77  not donated

# %%
transfusion.tail() # last 5 records
# Out:
#      Recency  Frequency  Monetary  Time        Class
# 743       23          2       500    38  not donated
# 744       21          2       500    52  not donated
# 745       23          3       750    62  not donated
# 746       39          1       250    39  not donated
# 747       72          1       250    72  not donated

# %%
transfusion.info() # dataframe structure summary
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 748 entries, 0 to 747
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Recency    748 non-null    int64
#  1   Frequency  748 non-null    int64
#  2   Monetary   748 non-null    int64
#  3   Time       748 non-null    int64
#  4   Class      748 non-null    object
# dtypes: int64(4), object(1)
# memory usage: 29.3+ KB

# %%
transfusion.describe()
# Out:
#           Recency   Frequency      Monetary        Time
# count  748.000000  748.000000    748.000000  748.000000
# mean     9.506684    5.514706   1378.676471   34.282086
# std      8.095396    5.839307   1459.826781   24.376714
# min      0.000000    1.000000    250.000000    2.000000
# 25%      2.750000    2.000000    500.000000   16.000000
# 50%      7.000000    4.000000   1000.000000   28.000000
# 75%     14.000000    7.000000   1750.000000   50.000000
# max     74.000000   50.000000  12500.000000   98.000000

# %%
transfusion.describe(include= 'object')
# Out:
#               Class
# count           748
# unique            2
# top     not donated
# freq            570

# %%
transfusion.columns.tolist()
# Out:
# ['Recency', 'Frequency', 'Monetary', 'Time', 'Class']

# %%
transfusion.iloc[-1]
# Out:
# Recency               72
# Frequency              1
# Monetary             250
# Time                  72
# Class        not donated
# Name: 747, dtype: object

# %%
transfusion.iloc[1: 20] # 1 - 19 records list
# Out:
#     Recency  Frequency  Monetary  Time        Class
# 1         0         13      3250    28      donated
# 2         1         16      4000    35      donated
# 3         2         20      5000    45      donated
# 4         1         24      6000    77  not donated
# 5         4          4      1000     4  not donated
# 6         2          7      1750    14      donated
# 7         1         12      3000    35  not donated
# 8         2          9      2250    22      donated
# 9         5         46     11500    98      donated
# 10        4         23      5750    58  not donated
# 11        0          3       750     4  not donated
# 12        2         10      2500    28      donated
# 13        1         13      3250    47  not donated
# 14        2          6      1500    15      donated
# 15        2          5      1250    11      donated
# 16        2         14      3500    48      donated
# 17        2         15      3750    49      donated
# ...

# %%
transfusion.iloc[1: 16,:3] # with first 5 col
# Out:
#     Recency  Frequency  Monetary
# 1         0         13      3250
# 2         1         16      4000
# 3         2         20      5000
# 4         1         24      6000
# 5         4          4      1000
# 6         2          7      1750
# 7         1         12      3000
# 8         2          9      2250
# 9         5         46     11500
# 10        4         23      5750
# 11        0          3       750
# 12        2         10      2500
# 13        1         13      3250
# 14        2          6      1500
# 15        2          5      1250

# %%
# 15 records with last 3 col
transfusion.iloc[:16,[-1,-2,-3]]
# Out:
#           Class  Time  Monetary
# 0       donated    98     12500
# 1       donated    28      3250
# 2       donated    35      4000
# 3       donated    45      5000
# 4   not donated    77      6000
# 5   not donated     4      1000
# 6       donated    14      1750
# 7   not donated    35      3000
# 8       donated    22      2250
# 9       donated    98     11500
# 10  not donated    58      5750
# 11  not donated     4       750
# 12      donated    28      2500
# 13  not donated    47      3250
# 14      donated    15      1500
# 15      donated    11      1250

# %%
# selecting a single col 
transfusion['Monetary']
# Out:
# 0      12500
# 1       3250
# 2       4000
# 3       5000
# 4       6000
#        ...
# 743      500
# 744      500
# 745      750
# 746      250
# 747      250
# Name: Monetary, Length: 748, dtype: int64

# %%
transfusion['Monetary'].plot(figsize=[10,5],color='lime')
# Out:
# <AxesSubplot: >

# %%
transfusion['Monetary'].plot(figsize=[10,5],kind='bar')
# Out:
# <AxesSubplot: >

# %%
transfusion['Frequency'].plot(figsize=[10,5],kind='hist',bins=20,color='purple')
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
transfusion[['Monetary','Frequency','Recency','Time']].plot(figsize=[20,8],kind='hist',color=['red','blue','green','orange'],bins=10,
subplots=True, layout=(1,4))
# Out:
# array([[<AxesSubplot: ylabel='Frequency'>,
#         <AxesSubplot: ylabel='Frequency'>,
#         <AxesSubplot: ylabel='Frequency'>,
#         <AxesSubplot: ylabel='Frequency'>]], dtype=object)

# %%
transfusion[['Monetary','Recency']].plot(figsize=[10,5],kind='pie',
subplots=True,layout=(1,2))
# Out:
# array([[<AxesSubplot: ylabel='Monetary'>,
#         <AxesSubplot: ylabel='Recency'>]], dtype=object)
